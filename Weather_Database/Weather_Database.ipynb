# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
# Import citipy
from citipy import citipy
# Import API key
from config import weather_api_key
# Import the time library and datetime module
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Start an empty list to hold weather data.
city_data =[]

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitdue and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Initial counters to log cities.
record_count = 1
set_count = 1

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
#     Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count}|{city}')
#     Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
#                           "Date": city_date,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1|sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 1|bethel
# Processing Record 3 of Set 1|souillac
# Processing Record 4 of Set 1|palmer
# Processing Record 5 of Set 1|mosquera
# Processing Record 6 of Set 1|lebu
# Processing Record 7 of Set 1|atuona
# Processing Record 8 of Set 1|ranfurly
# Processing Record 9 of Set 1|kroya
# Processing Record 10 of Set 1|butaritari
# Processing Record 11 of Set 1|qaanaaq
# Processing Record 12 of Set 1|sitka
# Processing Record 13 of Set 1|rikitea
# Processing Record 14 of Set 1|taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1|salto
# Processing Record 16 of Set 1|muros
# Processing Record 17 of Set 1|port alfred
# Processing Record 18 of Set 1|albany
# Processing Record 19 of Set 1|punta arenas
# Processing Record 20 of Set 1|khatanga
# Processing Record 21 of Set 1|macklin
# Processing Record 22 of Set 1|cozumel
# Processing Record 23 of Set 1|bredasdorp
# Processing Record 24 of Set 1|harper
# Processing Record 25 of Set 1|vaini
# Processing Record 26 of Set 1|ternate
# Processing Record 27 of Set 1|payo
# Processing Record 28 of Set 1|barcelona
# Processing Record 29 of Set 1|umarkot
# Processing Record 30 of Set 1|biak
# Processing Record 31 of Set 1|hermanus
# Processing Record 32 of Set 1|puerto ayora
# Processing Record 33 of Set 1|yerbogachen
# Processing Record 34 of Set 1|dawlatabad
# Processing Record 35 of Set 1|kloulklubed
# Processing Record 36 of Set 1|bluff
# Processing Record 37 of Set 1|awbari
# Processing Record 38 of Set 1|kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 1|dikson
# Processing Record 40 of Set 1|himora
# City not found. Skipping...
# Processing Record 41 of Set 1|malakal
# Processing Record 42 of Set 1|chany
# Processing Record 43 of Set 1|neiafu
# Processing Record 44 of Set 1|sao filipe
# Processing Record 45 of Set 1|tuktoyaktuk
# Processing Record 46 of Set 1|waingapu
# Processing Record 47 of Set 1|nikolskoye
# Processing Record 48 of Set 1|saint-philippe
# Processing Record 49 of Set 1|nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 1|norman wells
# Processing Record 1 of Set 2|yeppoon
# Processing Record 2 of Set 2|barrow
# Processing Record 3 of Set 2|hobart
# Processing Record 4 of Set 2|pontes e lacerda
# Processing Record 5 of Set 2|gerzat
# Processing Record 6 of Set 2|tucurui
# Processing Record 7 of Set 2|jamestown
# Processing Record 8 of Set 2|busselton
# Processing Record 9 of Set 2|victoria
# Processing Record 10 of Set 2|saint-malo
# Processing Record 11 of Set 2|byron bay
# Processing Record 12 of Set 2|lata
# Processing Record 13 of Set 2|georgetown
# Processing Record 14 of Set 2|namibe
# Processing Record 15 of Set 2|jaguarari
# Processing Record 16 of Set 2|machilipatnam
# Processing Record 17 of Set 2|gescher
# Processing Record 18 of Set 2|faanui
# Processing Record 19 of Set 2|ushuaia
# Processing Record 20 of Set 2|kaoma
# Processing Record 21 of Set 2|saskylakh
# Processing Record 22 of Set 2|rawson
# Processing Record 23 of Set 2|nara
# Processing Record 24 of Set 2|kuah
# Processing Record 25 of Set 2|tawkar
# City not found. Skipping...
# Processing Record 26 of Set 2|karakol
# Processing Record 27 of Set 2|abha
# Processing Record 28 of Set 2|mataura
# Processing Record 29 of Set 2|kruisfontein
# Processing Record 30 of Set 2|yellowknife
# Processing Record 31 of Set 2|birao
# Processing Record 32 of Set 2|kodinsk
# Processing Record 33 of Set 2|luanda
# Processing Record 34 of Set 2|bassila
# Processing Record 35 of Set 2|grand gaube
# Processing Record 36 of Set 2|matamoros
# Processing Record 37 of Set 2|ribeira grande
# Processing Record 38 of Set 2|paka
# Processing Record 39 of Set 2|kapaa
# Processing Record 40 of Set 2|la ronge
# Processing Record 41 of Set 2|flinders
# Processing Record 42 of Set 2|katrineholm
# Processing Record 43 of Set 2|nanortalik
# Processing Record 44 of Set 2|wittmund
# Processing Record 45 of Set 2|tigre
# Processing Record 46 of Set 2|marcona
# City not found. Skipping...
# Processing Record 47 of Set 2|mar del plata
# Processing Record 48 of Set 2|ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 2|san antonio
# Processing Record 50 of Set 2|pemangkat
# Processing Record 1 of Set 3|avarua
# Processing Record 2 of Set 3|sindor
# Processing Record 3 of Set 3|nalbari
# Processing Record 4 of Set 3|vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3|talah
# City not found. Skipping...
# Processing Record 6 of Set 3|port macquarie
# Processing Record 7 of Set 3|san pedro
# Processing Record 8 of Set 3|axim
# Processing Record 9 of Set 3|maputo
# Processing Record 10 of Set 3|road town
# Processing Record 11 of Set 3|corn island
# Processing Record 12 of Set 3|hilo
# Processing Record 13 of Set 3|bambamarca
# Processing Record 14 of Set 3|tuatapere
# Processing Record 15 of Set 3|dolores
# Processing Record 16 of Set 3|dumas
# Processing Record 17 of Set 3|belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3|chokurdakh
# Processing Record 19 of Set 3|acapulco
# Processing Record 20 of Set 3|los llanos de aridane
# Processing Record 21 of Set 3|gat
# Processing Record 22 of Set 3|ponta do sol
# Processing Record 23 of Set 3|mahebourg
# Processing Record 24 of Set 3|taltal
# Processing Record 25 of Set 3|vestmanna
# Processing Record 26 of Set 3|toftir
# City not found. Skipping...
# Processing Record 27 of Set 3|constitucion
# Processing Record 28 of Set 3|geraldton
# Processing Record 29 of Set 3|klaksvik
# Processing Record 30 of Set 3|ardakan
# Processing Record 31 of Set 3|voh
# Processing Record 32 of Set 3|mozhga
# Processing Record 33 of Set 3|leningradskiy
# Processing Record 34 of Set 3|komsomolskiy
# Processing Record 35 of Set 3|longyearbyen
# Processing Record 36 of Set 3|wewak
# Processing Record 37 of Set 3|husavik
# Processing Record 38 of Set 3|vorotynets
# Processing Record 39 of Set 3|mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 3|labuhan
# Processing Record 41 of Set 3|valle de allende
# Processing Record 42 of Set 3|krasnoselkup
# Processing Record 43 of Set 3|rocha
# Processing Record 44 of Set 3|college
# Processing Record 45 of Set 3|bilma
# Processing Record 46 of Set 3|surt
# Processing Record 47 of Set 3|cape town
# Processing Record 48 of Set 3|nampula
# Processing Record 49 of Set 3|ube
# Processing Record 50 of Set 3|pangkalanbuun
# Processing Record 1 of Set 4|ostrovnoy
# Processing Record 2 of Set 4|new norfolk
# Processing Record 3 of Set 4|egvekinot
# Processing Record 4 of Set 4|shelabolikha
# Processing Record 5 of Set 4|san lorenzo
# Processing Record 6 of Set 4|conde
# Processing Record 7 of Set 4|tiksi
# Processing Record 8 of Set 4|lunenburg
# Processing Record 9 of Set 4|lalomanu
# City not found. Skipping...
# Processing Record 10 of Set 4|sydney mines
# Processing Record 11 of Set 4|lorengau
# Processing Record 12 of Set 4|kaitangata
# Processing Record 13 of Set 4|svetlogorsk
# Processing Record 14 of Set 4|buchanan
# Processing Record 15 of Set 4|baiyin
# Processing Record 16 of Set 4|umm kaddadah
# Processing Record 17 of Set 4|castro
# Processing Record 18 of Set 4|salinopolis
# Processing Record 19 of Set 4|lasa
# Processing Record 20 of Set 4|kolokani
# Processing Record 21 of Set 4|illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 4|ketchikan
# Processing Record 23 of Set 4|toora-khem
# Processing Record 24 of Set 4|lawton
# Processing Record 25 of Set 4|montepuez
# Processing Record 26 of Set 4|iquique
# Processing Record 27 of Set 4|isangel
# Processing Record 28 of Set 4|misratah
# Processing Record 29 of Set 4|hasaki
# Processing Record 30 of Set 4|port lincoln
# Processing Record 31 of Set 4|sidney
# Processing Record 32 of Set 4|rungata
# City not found. Skipping...
# Processing Record 33 of Set 4|airai
# Processing Record 34 of Set 4|severo-kurilsk
# Processing Record 35 of Set 4|sistranda
# Processing Record 36 of Set 4|east london
# Processing Record 37 of Set 4|kysyl-syr
# Processing Record 38 of Set 4|nemuro
# Processing Record 39 of Set 4|pevek
# Processing Record 40 of Set 4|myitkyina
# Processing Record 41 of Set 4|cabo san lucas
# Processing Record 42 of Set 4|kandete
# Processing Record 43 of Set 4|kathmandu
# Processing Record 44 of Set 4|poum
# Processing Record 45 of Set 4|tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 4|mokhsogollokh
# Processing Record 47 of Set 4|igunga
# Processing Record 48 of Set 4|kendari
# Processing Record 49 of Set 4|louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 4|ahipara
# Processing Record 1 of Set 5|puerto madryn
# Processing Record 2 of Set 5|dodge city
# Processing Record 3 of Set 5|zhenjiang
# Processing Record 4 of Set 5|west bay
# Processing Record 5 of Set 5|port elizabeth
# Processing Record 6 of Set 5|san cristobal
# Processing Record 7 of Set 5|itoman
# Processing Record 8 of Set 5|luderitz
# Processing Record 9 of Set 5|ilulissat
# Processing Record 10 of Set 5|palatka
# Processing Record 11 of Set 5|altamira
# Processing Record 12 of Set 5|attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 5|provideniya
# Processing Record 14 of Set 5|ilek
# Processing Record 15 of Set 5|meyungs
# City not found. Skipping...
# Processing Record 16 of Set 5|bonavista
# Processing Record 17 of Set 5|yumen
# Processing Record 18 of Set 5|buin
# Processing Record 19 of Set 5|upernavik
# Processing Record 20 of Set 5|vidim
# Processing Record 21 of Set 5|vavozh
# Processing Record 22 of Set 5|bubaque
# Processing Record 23 of Set 5|san carlos de bariloche
# Processing Record 24 of Set 5|antalaha
# Processing Record 25 of Set 5|palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 5|zaozerne
# Processing Record 27 of Set 5|tevriz
# Processing Record 28 of Set 5|ermoupolis
# Processing Record 29 of Set 5|ksenyevka
# City not found. Skipping...
# Processing Record 30 of Set 5|burnie
# Processing Record 31 of Set 5|chuy
# Processing Record 32 of Set 5|riberalta
# Processing Record 33 of Set 5|kununurra
# Processing Record 34 of Set 5|cerinza
# Processing Record 35 of Set 5|ambulu
# Processing Record 36 of Set 5|cayenne
# Processing Record 37 of Set 5|amderma
# City not found. Skipping...
# Processing Record 38 of Set 5|arman
# Processing Record 39 of Set 5|holguin
# Processing Record 40 of Set 5|genhe
# Processing Record 41 of Set 5|khuchni
# Processing Record 42 of Set 5|gulshat
# City not found. Skipping...
# Processing Record 43 of Set 5|shakiso
# Processing Record 44 of Set 5|suntar
# Processing Record 45 of Set 5|daru
# Processing Record 46 of Set 5|dum duma
# Processing Record 47 of Set 5|wagar
# Processing Record 48 of Set 5|meulaboh
# Processing Record 49 of Set 5|semibratovo
# Processing Record 50 of Set 5|hamilton
# Processing Record 1 of Set 6|coquimbo
# Processing Record 2 of Set 6|arraial do cabo
# Processing Record 3 of Set 6|tasiilaq
# Processing Record 4 of Set 6|biu
# Processing Record 5 of Set 6|yuli
# Processing Record 6 of Set 6|longyan
# Processing Record 7 of Set 6|shaunavon
# Processing Record 8 of Set 6|kodiak
# Processing Record 9 of Set 6|pisco
# Processing Record 10 of Set 6|ngaoundere
# Processing Record 11 of Set 6|nelson bay
# Processing Record 12 of Set 6|nguiu
# City not found. Skipping...
# Processing Record 13 of Set 6|caravelas
# Processing Record 14 of Set 6|alihe
# Processing Record 15 of Set 6|mount gambier
# Processing Record 16 of Set 6|grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 6|potgietersrus
# City not found. Skipping...
# Processing Record 18 of Set 6|samusu
# City not found. Skipping...
# Processing Record 19 of Set 6|namie
# Processing Record 20 of Set 6|imeni babushkina
# Processing Record 21 of Set 6|te anau
# Processing Record 22 of Set 6|vostok
# Processing Record 23 of Set 6|aksha
# Processing Record 24 of Set 6|carnarvon
# Processing Record 25 of Set 6|mareeba
# Processing Record 26 of Set 6|masterton
# Processing Record 27 of Set 6|brae
# Processing Record 28 of Set 6|suriapet
# Processing Record 29 of Set 6|coihaique
# Processing Record 30 of Set 6|narsaq
# Processing Record 31 of Set 6|sibu
# Processing Record 32 of Set 6|singkang
# Processing Record 33 of Set 6|srednekolymsk
# Processing Record 34 of Set 6|lagoa
# Processing Record 35 of Set 6|oreanda
# City not found. Skipping...
# Processing Record 36 of Set 6|korsakov
# Processing Record 37 of Set 6|skjervoy
# Processing Record 38 of Set 6|iqaluit
# Processing Record 39 of Set 6|dunedin
# Processing Record 40 of Set 6|half moon bay
# Processing Record 41 of Set 6|bac lieu
# Processing Record 42 of Set 6|niamey
# Processing Record 43 of Set 6|teahupoo
# Processing Record 44 of Set 6|ulaangom
# Processing Record 45 of Set 6|olafsvik
# Processing Record 46 of Set 6|itarema
# Processing Record 47 of Set 6|hauzenberg
# Processing Record 48 of Set 6|zavodoukovsk
# Processing Record 49 of Set 6|esteli
# Processing Record 50 of Set 6|morro bay
# Processing Record 1 of Set 7|taoudenni
# Processing Record 2 of Set 7|erdenet
# Processing Record 3 of Set 7|nahariyya
# Processing Record 4 of Set 7|mrirt
# City not found. Skipping...
# Processing Record 5 of Set 7|sao joao da barra
# Processing Record 6 of Set 7|hami
# Processing Record 7 of Set 7|valdepenas
# Processing Record 8 of Set 7|maldonado
# Processing Record 9 of Set 7|verkhnevilyuysk
# Processing Record 10 of Set 7|raudeberg
# Processing Record 11 of Set 7|hovd
# Processing Record 12 of Set 7|tungor
# Processing Record 13 of Set 7|nelidovo
# Processing Record 14 of Set 7|high level
# Processing Record 15 of Set 7|saint george
# Processing Record 16 of Set 7|george
# Processing Record 17 of Set 7|balikpapan
# Processing Record 18 of Set 7|inhambane
# Processing Record 19 of Set 7|saposoa
# Processing Record 20 of Set 7|sola
# Processing Record 21 of Set 7|mackay
# Processing Record 22 of Set 7|toliary
# City not found. Skipping...
# Processing Record 23 of Set 7|waipawa
# Processing Record 24 of Set 7|fortuna
# Processing Record 25 of Set 7|shingu
# Processing Record 26 of Set 7|chateaubelair
# Processing Record 27 of Set 7|vila franca do campo
# Processing Record 28 of Set 7|of
# City not found. Skipping...
# Processing Record 29 of Set 7|elat
# Processing Record 30 of Set 7|padang
# Processing Record 31 of Set 7|bathsheba
# Processing Record 32 of Set 7|bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 7|fort saint james
# Processing Record 34 of Set 7|adrar
# Processing Record 35 of Set 7|ishigaki
# Processing Record 36 of Set 7|kulykivka
# Processing Record 37 of Set 7|banda aceh
# Processing Record 38 of Set 7|antioquia
# Processing Record 39 of Set 7|muroto
# Processing Record 40 of Set 7|saint-francois
# Processing Record 41 of Set 7|new ulm
# Processing Record 42 of Set 7|ca mau
# Processing Record 43 of Set 7|rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 7|seoul
# Processing Record 45 of Set 7|pangody
# Processing Record 46 of Set 7|necochea
# Processing Record 47 of Set 7|teya
# Processing Record 48 of Set 7|shache
# Processing Record 49 of Set 7|glens falls
# Processing Record 50 of Set 7|barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 8|sai buri
# Processing Record 2 of Set 8|hithadhoo
# Processing Record 3 of Set 8|yar-sale
# Processing Record 4 of Set 8|eston
# Processing Record 5 of Set 8|lianzhou
# Processing Record 6 of Set 8|bowen
# Processing Record 7 of Set 8|deputatskiy
# Processing Record 8 of Set 8|senanga
# Processing Record 9 of Set 8|portland
# Processing Record 10 of Set 8|hihifo
# City not found. Skipping...
# Processing Record 11 of Set 8|clyde river
# Processing Record 12 of Set 8|la ciotat
# Processing Record 13 of Set 8|shenjiamen
# Processing Record 14 of Set 8|mahon
# Processing Record 15 of Set 8|buk
# Processing Record 16 of Set 8|puerto narino
# Processing Record 17 of Set 8|turlock
# Processing Record 18 of Set 8|general roca
# Processing Record 19 of Set 8|mitsamiouli
# Processing Record 20 of Set 8|pandhana
# Processing Record 21 of Set 8|havoysund
# Processing Record 22 of Set 8|sao felix do xingu
# Processing Record 23 of Set 8|vila velha
# Processing Record 24 of Set 8|santa isabel
# Processing Record 25 of Set 8|sao jose da coroa grande
# Processing Record 26 of Set 8|anloga
# Processing Record 27 of Set 8|sobolevo
# Processing Record 28 of Set 8|asau
# Processing Record 29 of Set 8|bacungan
# Processing Record 30 of Set 8|saint-joseph
# Processing Record 31 of Set 8|beisfjord
# Processing Record 32 of Set 8|honiara
# Processing Record 33 of Set 8|torbay
# Processing Record 34 of Set 8|beboto
# Processing Record 35 of Set 8|tunduru
# City not found. Skipping...
# Processing Record 36 of Set 8|artyk
# City not found. Skipping...
# Processing Record 37 of Set 8|aripuana
# Processing Record 38 of Set 8|lovrenc na pohorju
# Processing Record 39 of Set 8|puerto del rosario
# Processing Record 40 of Set 8|danielskuil
# Processing Record 41 of Set 8|port-gentil
# Processing Record 42 of Set 8|mana
# Processing Record 43 of Set 8|newport
# Processing Record 44 of Set 8|kerouane
# Processing Record 45 of Set 8|kokkola
# Processing Record 46 of Set 8|alofi
# Processing Record 47 of Set 8|ust-nera
# Processing Record 48 of Set 8|gimli
# Processing Record 49 of Set 8|laguna
# Processing Record 50 of Set 8|cidreira
# Processing Record 1 of Set 9|santa helena de goias
# Processing Record 2 of Set 9|cariamanga
# Processing Record 3 of Set 9|yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 4 of Set 9|nouadhibou
# Processing Record 5 of Set 9|yingcheng
# Processing Record 6 of Set 9|bengkulu
# Processing Record 7 of Set 9|wejherowo
# Processing Record 8 of Set 9|lebedyan
# Processing Record 9 of Set 9|sur
# Processing Record 10 of Set 9|touros
# Processing Record 11 of Set 9|yagodnoye
# Processing Record 12 of Set 9|anaconda
# Processing Record 13 of Set 9|praia grande
# Processing Record 14 of Set 9|zhanaozen
# Processing Record 15 of Set 9|marsa matruh
# Processing Record 16 of Set 9|aflu
# City not found. Skipping...
# Processing Record 17 of Set 9|thompson
# Processing Record 18 of Set 9|tres arroyos
# Processing Record 19 of Set 9|amazar
# Processing Record 20 of Set 9|gornopravdinsk
# Processing Record 21 of Set 9|maumere
# Processing Record 22 of Set 9|johi
# Processing Record 23 of Set 9|ribas do rio pardo
# Processing Record 24 of Set 9|saleaula
# City not found. Skipping...
# Processing Record 25 of Set 9|xining
# Processing Record 26 of Set 9|colares
# Processing Record 27 of Set 9|henties bay
# Processing Record 28 of Set 9|kailua
# Processing Record 29 of Set 9|kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 9|cherskiy
# Processing Record 31 of Set 9|acarau
# Processing Record 32 of Set 9|hualmay
# Processing Record 33 of Set 9|sakakah
# Processing Record 34 of Set 9|kahului
# Processing Record 35 of Set 9|lerwick
# Processing Record 36 of Set 9|requena
# Processing Record 37 of Set 9|ndele
# Processing Record 38 of Set 9|petrozavodsk
# Processing Record 39 of Set 9|esperance
# Processing Record 40 of Set 9|jega
# Processing Record 41 of Set 9|anjangaon
# Processing Record 42 of Set 9|jilin
# Processing Record 43 of Set 9|lagunas
# Processing Record 44 of Set 9|lingao
# Processing Record 45 of Set 9|tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 9|codrington
# Processing Record 47 of Set 9|pacific grove
# Processing Record 48 of Set 9|miracema do tocantins
# Processing Record 49 of Set 9|nabire
# Processing Record 50 of Set 9|isehara
# Processing Record 1 of Set 10|umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 10|carbonia
# Processing Record 3 of Set 10|holme
# Processing Record 4 of Set 10|la cruz
# Processing Record 5 of Set 10|morant bay
# Processing Record 6 of Set 10|warah
# Processing Record 7 of Set 10|ancud
# Processing Record 8 of Set 10|tuy hoa
# Processing Record 9 of Set 10|camocim
# Processing Record 10 of Set 10|omboue
# Processing Record 11 of Set 10|nome
# Processing Record 12 of Set 10|mixtepec
# City not found. Skipping...
# Processing Record 13 of Set 10|aksarka
# Processing Record 14 of Set 10|felidhoo
# City not found. Skipping...
# Processing Record 15 of Set 10|jumla
# Processing Record 16 of Set 10|vao
# Processing Record 17 of Set 10|ariquemes
# Processing Record 18 of Set 10|tabou
# Processing Record 19 of Set 10|papayal
# Processing Record 20 of Set 10|guerrero negro
# Processing Record 21 of Set 10|hofn
# Processing Record 22 of Set 10|talavera
# Processing Record 23 of Set 10|novoleushkovskaya
# Processing Record 24 of Set 10|san juan
# Processing Record 25 of Set 10|miles city
# Processing Record 26 of Set 10|saqqez
# Processing Record 27 of Set 10|getulio vargas
# Processing Record 28 of Set 10|olinda
# Processing Record 29 of Set 10|yalvac
# Processing Record 30 of Set 10|mouzakion
# City not found. Skipping...
# Processing Record 31 of Set 10|itaituba
# Processing Record 32 of Set 10|bardiyah
# Processing Record 33 of Set 10|jiazi
# Processing Record 34 of Set 10|kitob
# Processing Record 35 of Set 10|chumikan
# Processing Record 36 of Set 10|chamonix-mont-blanc
# Processing Record 37 of Set 10|camana
# Processing Record 38 of Set 10|trincomalee
# Processing Record 39 of Set 10|port blair
# Processing Record 40 of Set 10|ayer itam
# City not found. Skipping...
# Processing Record 41 of Set 10|nuuk
# Processing Record 42 of Set 10|asfi
# Processing Record 43 of Set 10|bambous virieux
# Processing Record 44 of Set 10|biharamulo
# Processing Record 45 of Set 10|nouakchott
# Processing Record 46 of Set 10|diplo
# Processing Record 47 of Set 10|villa bruzual
# Processing Record 48 of Set 10|udachnyy
# Processing Record 49 of Set 10|kasongo-lunda
# Processing Record 50 of Set 10|karasjok
# Processing Record 1 of Set 11|saldanha
# Processing Record 2 of Set 11|sabaudia
# Processing Record 3 of Set 11|sucua
# Processing Record 4 of Set 11|koroni
# Processing Record 5 of Set 11|tazovskiy
# Processing Record 6 of Set 11|mettur
# Processing Record 7 of Set 11|linhares
# Processing Record 8 of Set 11|drayton valley
# Processing Record 9 of Set 11|scarborough
# Processing Record 10 of Set 11|carroll
# Processing Record 11 of Set 11|sabang
# Processing Record 12 of Set 11|moranbah
# Processing Record 13 of Set 11|buala
# Processing Record 14 of Set 11|tanabe
# Processing Record 15 of Set 11|aklavik
# Processing Record 16 of Set 11|yukhnov
# Processing Record 17 of Set 11|zheleznodorozhnyy
# Processing Record 18 of Set 11|kadaya
# Processing Record 19 of Set 11|jining
# Processing Record 20 of Set 11|pimampiro
# Processing Record 21 of Set 11|cockburn town
# Processing Record 22 of Set 11|lahij
# Processing Record 23 of Set 11|otaru
# Processing Record 24 of Set 11|dandong
# Processing Record 25 of Set 11|vanimo
# Processing Record 26 of Set 11|mecca
# Processing Record 27 of Set 11|sangar
# Processing Record 28 of Set 11|bridlington
# Processing Record 29 of Set 11|riyaq
# City not found. Skipping...
# Processing Record 30 of Set 11|miri
# Processing Record 31 of Set 11|ponta delgada
# Processing Record 32 of Set 11|berlevag
# Processing Record 33 of Set 11|lavrentiya
# Processing Record 34 of Set 11|tondon
# Processing Record 35 of Set 11|cairns
# Processing Record 36 of Set 11|kizukuri
# Processing Record 37 of Set 11|tuim
# Processing Record 38 of Set 11|haibowan
# City not found. Skipping...
# Processing Record 39 of Set 11|bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 11|mao
# Processing Record 41 of Set 11|verkhovyna
# Processing Record 42 of Set 11|sawasawa
# City not found. Skipping...
# Processing Record 43 of Set 11|anadyr
# Processing Record 44 of Set 11|kwakoa
# Processing Record 45 of Set 11|rio bueno
# Processing Record 46 of Set 11|ler
# Processing Record 47 of Set 11|ambilobe
# Processing Record 48 of Set 11|basco
# Processing Record 49 of Set 11|chernyshevskiy
# Processing Record 50 of Set 11|los andes
# Processing Record 1 of Set 12|pochutla
# Processing Record 2 of Set 12|tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 12|salym
# Processing Record 4 of Set 12|taburi
# City not found. Skipping...
# Processing Record 5 of Set 12|qobustan
# Processing Record 6 of Set 12|lujan
# Processing Record 7 of Set 12|puerto escondido
# Processing Record 8 of Set 12|hauterive
# Processing Record 9 of Set 12|amahai
# Processing Record 10 of Set 12|merrill
# Processing Record 11 of Set 12|stephenville
# Processing Record 12 of Set 12|pallasovka
# Processing Record 13 of Set 12|santa isabel do rio negro
# Processing Record 14 of Set 12|ambon
# Processing Record 15 of Set 12|akyab
# Processing Record 16 of Set 12|poso
# Processing Record 17 of Set 12|warqla
# City not found. Skipping...
# Processing Record 18 of Set 12|harlingen
# Processing Record 19 of Set 12|imisli
# City not found. Skipping...
# Processing Record 20 of Set 12|manjeshwar
# Processing Record 21 of Set 12|vestmannaeyjar
# Processing Record 22 of Set 12|borovoy
# Processing Record 23 of Set 12|kingman
# Processing Record 24 of Set 12|cacoal
# Processing Record 25 of Set 12|tekari
# Processing Record 26 of Set 12|shimanovsk
# Processing Record 27 of Set 12|tsiroanomandidy
# Processing Record 28 of Set 12|darnah
# Processing Record 29 of Set 12|astipalaia
# City not found. Skipping...
# Processing Record 30 of Set 12|chapais
# Processing Record 31 of Set 12|vacaria
# Processing Record 32 of Set 12|fukue
# Processing Record 33 of Set 12|chak azam sahu
# Processing Record 34 of Set 12|nenjiang
# Processing Record 35 of Set 12|kawalu
# Processing Record 36 of Set 12|barbar
# City not found. Skipping...
# Processing Record 37 of Set 12|jorpeland
# Processing Record 38 of Set 12|soe
# Processing Record 39 of Set 12|la romana
# Processing Record 40 of Set 12|katsuura
# Processing Record 41 of Set 12|hobyo
# Processing Record 42 of Set 12|san policarpo
# Processing Record 43 of Set 12|plerin
# Processing Record 44 of Set 12|strezhevoy
# Processing Record 45 of Set 12|intipuca
# Processing Record 46 of Set 12|petropavlovsk-kamchatskiy
# Processing Record 47 of Set 12|ginda
# Processing Record 48 of Set 12|karamea
# City not found. Skipping...
# Processing Record 49 of Set 12|luwuk
# Processing Record 50 of Set 12|yining
# Processing Record 1 of Set 13|disraeli
# Processing Record 2 of Set 13|sisimiut
# Processing Record 3 of Set 13|grants pass
# Processing Record 4 of Set 13|arlit
# Processing Record 5 of Set 13|manta
# Processing Record 6 of Set 13|troy
# Processing Record 7 of Set 13|am timan
# Processing Record 8 of Set 13|grindsted
# Processing Record 9 of Set 13|balud
# Processing Record 10 of Set 13|san juan de los morros
# Processing Record 11 of Set 13|progreso
# Processing Record 12 of Set 13|pecos
# Processing Record 13 of Set 13|lingyuan
# Processing Record 14 of Set 13|hirara
# Processing Record 15 of Set 13|tarimoro
# Processing Record 16 of Set 13|kangaatsiaq
# Processing Record 17 of Set 13|samarai
# Processing Record 18 of Set 13|kirkwall
# Processing Record 19 of Set 13|minsk
# Processing Record 20 of Set 13|roma
# Processing Record 21 of Set 13|athabasca
# Processing Record 22 of Set 13|lagos
# Processing Record 23 of Set 13|kudahuvadhoo
# Processing Record 24 of Set 13|ozgon
# City not found. Skipping...
# Processing Record 25 of Set 13|mount isa
# Processing Record 26 of Set 13|pafos
# Processing Record 27 of Set 13|kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 13|boueni
# Processing Record 29 of Set 13|batagay-alyta
# Processing Record 30 of Set 13|linjiang
# Processing Record 31 of Set 13|atambua
# Processing Record 32 of Set 13|lompoc
# Processing Record 33 of Set 13|yulara
# Processing Record 34 of Set 13|jatai
# Processing Record 35 of Set 13|det udom
# Processing Record 36 of Set 13|calvia
# Processing Record 37 of Set 13|hirata
# Processing Record 38 of Set 13|batsfjord
# Processing Record 39 of Set 13|jinchang
# Processing Record 40 of Set 13|bourail
# Processing Record 41 of Set 13|itacoatiara
# Processing Record 42 of Set 13|tucupita
# Processing Record 43 of Set 13|kyshtovka
# Processing Record 44 of Set 13|haines junction
# Processing Record 45 of Set 13|salalah
# Processing Record 46 of Set 13|steamboat springs
# Processing Record 47 of Set 13|alice springs
# Processing Record 48 of Set 13|nacala
# Processing Record 49 of Set 13|edgewater
# Processing Record 50 of Set 13|usak
# Processing Record 1 of Set 14|point pleasant
# Processing Record 2 of Set 14|poya
# Processing Record 3 of Set 14|abonnema
# Processing Record 4 of Set 14|kampene
# Processing Record 5 of Set 14|atar
# Processing Record 6 of Set 14|manakara
# Processing Record 7 of Set 14|tautira
# Processing Record 8 of Set 14|eskil
# Processing Record 9 of Set 14|lugovoy
# Processing Record 10 of Set 14|marsh harbour
# Processing Record 11 of Set 14|avanigadda
# Processing Record 12 of Set 14|taksimo
# Processing Record 13 of Set 14|khani
# Processing Record 14 of Set 14|quelimane
# Processing Record 15 of Set 14|yakima
# Processing Record 16 of Set 14|karoi
# Processing Record 17 of Set 14|kieta
# Processing Record 18 of Set 14|yarke pole
# Processing Record 19 of Set 14|pedernales
# Processing Record 20 of Set 14|mentok
# City not found. Skipping...
# Processing Record 21 of Set 14|sunrise manor
# Processing Record 22 of Set 14|richards bay
# Processing Record 23 of Set 14|elkton
# Processing Record 24 of Set 14|belmonte
# Processing Record 25 of Set 14|bisho
# Processing Record 26 of Set 14|sao lourenco do oeste
# Processing Record 27 of Set 14|duki
# Processing Record 28 of Set 14|talcahuano
# Processing Record 29 of Set 14|cascais
# Processing Record 30 of Set 14|conceicao do araguaia
# Processing Record 31 of Set 14|hambantota
# Processing Record 32 of Set 14|jarjis
# City not found. Skipping...
# Processing Record 33 of Set 14|kinablangan
# Processing Record 34 of Set 14|san fernando
# Processing Record 35 of Set 14|morelos
# Processing Record 36 of Set 14|qasigiannguit
# Processing Record 37 of Set 14|paamiut
# Processing Record 38 of Set 14|homer
# Processing Record 39 of Set 14|havre-saint-pierre
# Processing Record 40 of Set 14|fairbanks
# Processing Record 41 of Set 14|estevan
# Processing Record 42 of Set 14|lethbridge
# Processing Record 43 of Set 14|san rafael
# Processing Record 44 of Set 14|bereda
# Processing Record 45 of Set 14|ranong
# Processing Record 46 of Set 14|kargasok
# Processing Record 47 of Set 14|astana
# Processing Record 48 of Set 14|quatre cocos
# Processing Record 49 of Set 14|margate
# Processing Record 50 of Set 14|nantucket
# Processing Record 1 of Set 15|ouadda
# Processing Record 2 of Set 15|eureka
# Processing Record 3 of Set 15|salair
# Processing Record 4 of Set 15|milingimbi
# City not found. Skipping...
# Processing Record 5 of Set 15|potosi
# Processing Record 6 of Set 15|sataua
# City not found. Skipping...
# Processing Record 7 of Set 15|kilindoni
# Processing Record 8 of Set 15|moose factory
# Processing Record 9 of Set 15|mabaruma
# Processing Record 10 of Set 15|marstal
# Processing Record 11 of Set 15|charleston
# Processing Record 12 of Set 15|gao
# Processing Record 13 of Set 15|isla mujeres
# Processing Record 14 of Set 15|port hedland
# Processing Record 15 of Set 15|gallup
# Processing Record 16 of Set 15|merauke
# Processing Record 17 of Set 15|mbacke
# City not found. Skipping...
# Processing Record 18 of Set 15|comodoro rivadavia
# Processing Record 19 of Set 15|sapa
# Processing Record 20 of Set 15|zwedru
# Processing Record 21 of Set 15|plettenberg bay
# Processing Record 22 of Set 15|gaogou
# Processing Record 23 of Set 15|takoradi
# Processing Record 24 of Set 15|boden
# Processing Record 25 of Set 15|mae sai
# Processing Record 26 of Set 15|norrtalje
# Processing Record 27 of Set 15|ximei
# Processing Record 28 of Set 15|mount darwin
# Processing Record 29 of Set 15|grindavik
# Processing Record 30 of Set 15|amapa
# Processing Record 31 of Set 15|rossosh
# Processing Record 32 of Set 15|sorland
# Processing Record 33 of Set 15|tianpeng
# Processing Record 34 of Set 15|emerald
# Processing Record 35 of Set 15|tromso
# Processing Record 36 of Set 15|iwanai
# Processing Record 37 of Set 15|galle
# Processing Record 38 of Set 15|kambove
# Processing Record 39 of Set 15|guanica
# Processing Record 40 of Set 15|lolua
# City not found. Skipping...
# Processing Record 41 of Set 15|cockburn harbour
# City not found. Skipping...
# Processing Record 42 of Set 15|manaus
# Processing Record 43 of Set 15|jinchengjiang
# City not found. Skipping...
# Processing Record 44 of Set 15|spearfish
# Processing Record 45 of Set 15|sechura
# Processing Record 46 of Set 15|olga
# Processing Record 47 of Set 15|beira
# Processing Record 48 of Set 15|muisne
# Processing Record 49 of Set 15|elko
# Processing Record 50 of Set 15|zhanakorgan
# Processing Record 1 of Set 16|viligili
# City not found. Skipping...
# Processing Record 2 of Set 16|saint anthony
# Processing Record 3 of Set 16|walvis bay
# Processing Record 4 of Set 16|qostanay
# Processing Record 5 of Set 16|salta
# Processing Record 6 of Set 16|lakes entrance
# Processing Record 7 of Set 16|verkhoyansk
# Processing Record 8 of Set 16|nerchinskiy zavod
# Processing Record 9 of Set 16|masjed-e soleyman
# City not found. Skipping...
# Processing Record 10 of Set 16|harrisburg
# Processing Record 11 of Set 16|ayagoz
# Processing Record 12 of Set 16|north bend
# Processing Record 13 of Set 16|minab
# Processing Record 14 of Set 16|zambezi
# Processing Record 15 of Set 16|chegem
# Processing Record 16 of Set 16|maceio
# Processing Record 17 of Set 16|lokosovo
# Processing Record 18 of Set 16|sagua de tanamo
# Processing Record 19 of Set 16|jabinyanah
# Processing Record 20 of Set 16|holeby
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 699

# %%
# Convert to dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#        City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Bethel  41.3712 -73.4140     64.02        78          65        1.01
# 1  Souillac -20.5167  57.5167     74.35        73          21        5.46
# 2    Palmer  42.1584 -72.3287     64.72        67          83        1.99
# 3  Mosquera   4.7059 -74.2302     62.69        72          75        6.91
# 4      Lebu -37.6167 -73.6500     60.12        72         100        7.96
#
#   Country Current Description
# 0      US       broken clouds
# 1      MU          few clouds
# 2      US       broken clouds
# 3      CO       broken clouds
# 4      CL     overcast clouds

# %%
city_data_df = city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]
city_data_df.head()
# Out:
#        City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    Bethel      US  41.3712 -73.4140     64.02        78          65
# 1  Souillac      MU -20.5167  57.5167     74.35        73          21
# 2    Palmer      US  42.1584 -72.3287     64.72        67          83
# 3  Mosquera      CO   4.7059 -74.2302     62.69        72          75
# 4      Lebu      CL -37.6167 -73.6500     60.12        72         100
#
#    Wind Speed Current Description
# 0        1.01       broken clouds
# 1        5.46          few clouds
# 2        1.99       broken clouds
# 3        6.91       broken clouds
# 4        7.96     overcast clouds

# %%
# Save .csv
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
